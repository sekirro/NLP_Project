# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

df = pd.read_csv('sft.csv')

x = df['Step']
y = df['Training Loss']

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('Training Loss')
plt.title('Training Loss')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

plt.plot(x, y)
plt.show()
# Out:
# C:\Users\13686\AppData\Local\Temp\ipykernel_29500\3548673742.py:14: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()  # 显示图例

# %%
df = pd.read_csv('dpo.csv')

x = df['Step']
y = df['Training Loss']

plt.plot(x, y)

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('Training Loss')
plt.title('Training Loss')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\13686\AppData\Local\Temp\ipykernel_28080\3384248276.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()  # 显示图例

# %%
# 读取数据
df = pd.read_csv('dpo.csv')

# 创建图表
plt.figure(figsize=(10, 6))  # 设置图表大小

# 绘制两条线
plt.plot(df['Step'], df['rewards / chosen'], label='Chosen', color='blue')
plt.plot(df['Step'], df['rewards / rejected'], label='Rejected', color='red')

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('Rewards')
plt.title('Chosen vs Rejected Rewards')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图表
plt.show()

# %%
# 读取数据
df = pd.read_csv('dpo.csv')

# 计算差值
df['rewards_margin'] = df['rewards / chosen'] - df['rewards / rejected']

# 创建图表
plt.figure(figsize=(10, 6))  # 设置图表大小

# 绘制差值线
plt.plot(df['Step'], df['rewards_margin'], label='Chosen - Rejected', color='purple')

# 添加零线参考
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.5)

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('Rewards Margin (Chosen - Rejected)')
plt.title('Rewards Margin (Chosen - Rejected)')
plt.legend()  # 显示图例

# 添加网格线
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图表
plt.show()

# %%
df = pd.read_csv('dpo.csv')

x = df['Step']
y = df['rewards / accuracies']

plt.plot(x, y)

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('rewards / accuracies')
plt.title('rewards / accuracies')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\13686\AppData\Local\Temp\ipykernel_28080\1735225708.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()  # 显示图例

# %%
df = pd.read_csv('dpo.csv')

x = df['Step']
y = df['rewards / margins']

plt.plot(x, y)

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('rewards / margins')
plt.title('rewards / margins')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

plt.show()
# Out:
# C:\Users\13686\AppData\Local\Temp\ipykernel_28080\1045790713.py:12: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()  # 显示图例

# %%
# 读取数据
df = pd.read_csv('dpo.csv')

# 创建图表
plt.figure(figsize=(10, 6))  # 设置图表大小

# 绘制两条线
plt.plot(df['Step'], df['logps / chosen'], label='Chosen', color='blue')
plt.plot(df['Step'], df['logps / rejected'], label='Rejected', color='red')

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('logps / chosen')
plt.title('logps / chosen')
plt.legend()  # 显示图例

# 添加网格线（可选）
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图表
plt.show()

# %%
# 读取数据
df = pd.read_csv('dpo.csv')

# 计算差值
df['logps_margin'] = df['logps / chosen']/df['logps / rejected']

# 创建图表
plt.figure(figsize=(10, 6))  # 设置图表大小

# 绘制差值线
plt.plot(df['Step'], df['logps_margin'], label='Chosen - Rejected', color='purple')

# 添加零线参考
plt.axhline(y=0, color='gray', linestyle='--', alpha=0.5)

# 添加标签和标题
plt.xlabel('Step')
plt.ylabel('Rewards Margin (Chosen - Rejected)')
plt.title('Rewards Margin (Chosen - Rejected)')
plt.legend()  # 显示图例

# 添加网格线
plt.grid(True, linestyle='--', alpha=0.7)

# 显示图表
plt.show()
